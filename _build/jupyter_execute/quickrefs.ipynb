# %% [markdown]
# # Quick References
#
# ## Classroom and Virtual Attendance Information
# - **Location**: Wolfe **E2014** (Sommer Hall), East Baltimore Campus. You're encouraged to join the in-person experience for enriched learning.
# - **Zoom Online Classroom**: [Join Zoom Meeting](https://jhjhm.zoom.us/j/93892874220)
#    - Sessions <strike>and labs</strike> will be recorded and stored in the cloud for 120 days for review and reference.
#       + [Week 1](https://jhjhm.zoom.us/rec/share/DaJ0II-S-aiOGrO8aGBWCziouCkEmkPnWQSkNCtEkb92S5imdWJykcZIygy3dStY.HAdUWzYMymPB0lAx?startTime=1711483399000)
#       + [Week 2](https://jhjhm.zoom.us/rec/share/v0Hwo06HC6Mby2Fp6dJKdlLXB8P3TYwcscib1nj-ljh8whJadZckD8OyKAF4jtn9.Pt8j7PHoRvKawamq)
#       + [Week 3](https://jhjhm.zoom.us/rec/share/sQ73RiIs3Pn4dQfQL7oLHZDII4DNnkIekLXjbqERMz-OLHKnqWV4ZocMaxATNacG.XDVtipYWJidTFCZ7?startTime=1712692223000)
#       + [Week 4](https://jhjhm.zoom.us/rec/share/eRYyVng_HS4t05D6Uvp3CewKWEGds07xiecMTVQmY88axN-x74wlnAtw4PGJhdTA.xUL4EdYE8w7t24cR?startTime=1713297483000)
#       + Week 5
#       + Week 6
#       + Week 7
#       + Week 8
#    - Screen sharing during class is recommended for effective troubleshooting.
#
# ## Course Materials and Communications
# - **Syllabus**: [View Syllabus](https://publichealth.jhu.edu/course/38942)
# - **CoursePlus Portal**: [Access Course Materials and Forums](https://courseplus.jhu.edu/core/index.cfm/go/syl:syl.public.view/coid/21075/)
#    - Contains video passcodes, discussion forums, and lab Dropbox for assignments.
#
# ## Course Team Contacts
# - **Instructor**: Abimereki Muzaale, Email: muzaale@jhmi.edu
# - **Analytical Mentor**:
#    - Vincent Jin, Email: zjin26@jhmi.edu
#
# - **Teaching Assistants**:
#    - Hejingzi (Monica), Email: hjia11@jhu.edu
#
# ## Labs Schedule/Office Hour
# - Time: Wednesdays from 2pm to 3pm
# - Room: TBA
# - Zoom [Link](https://JHUBlueJays.zoom.us/j/2446367355)
#    - **Lab 1/Week 2**: [Lab 1 Instructions](lab1.md)  (04/01 - 04/05)
#    - **Lab 2/Week 3**: [Lab 2 Instructions](https://jhustata.github.io/intermediate/chapter3.html#lab) (04/08 - 04/12)
#    - **Lab 3/Week 4**: [Lab 3 Instructions](https://jhustata.github.io/intermediate/chapter3.html#lab)  (04/15 - 04/19)
#    - **Lab 4/Week 5**: [Lab 4 Instructions](https://jhustata.github.io/intermediate/chapter4.html#lab)  (04/22 - 04/26)
#    - **Lab 5/Week 6**: Lab 5 Instructions  (04/29 - 05/02)
#
# - Ensure to check the specific dates and access the provided solutions for self-review.
#
# ## Homework Assignments
# Assignments are a crucial part of the coursework, allowing you to apply what you've learned:
# - **HW 1**: [Assignment 1](https://jhustata.github.io/intermediate/chapter1.html#homework) Due 04/04 | Solution
# - **HW 2**: [Assignment 2](https://jhustata.github.io/intermediate/chapter2.html#homework) Due 04/11 | Solution
# - **HW 3**: [Assignment 3](https://jhustata.github.io/intermediate/chapter3.html#homework) Due 04/18 | Solution
# - **HW 4**: [Assignment 4](https://jhustata.github.io/intermediate/chapter4.html#homework-instructions) Due 04/25 | Solution
# - **HW 5**: Assignment 5 Due 05/02 | Solution
# - **HW 6**: Assignment 6 Due 05/09 | Solution
# - **HW 7**: Assignment 7 Due 05/16 | Solution
#
# - Make sure to submit by the due dates and refer to the solutions for feedback.
#
# ## Datasets and Supplementary Materials
# The course utilizes various datasets and Stata do-files, which are integral for lab exercises and homework:
# - **Datasets**: Available for download or `direct import`, including `transplants.dta`, `donors.dta`, and more, alongside their respective `.txt` versions available for preview.
#    + [transplants.dta](https://github.com/jhustata/intermediate/raw/main/transplants.dta)
#    + [transplants.txt](https://github.com/jhustata/intermediate/raw/main/transplants.txt)
#    + [donors.dta](https://github.com/jhustata/intermediate/raw/main//donors.dta)
#    + [donors.txt](https://github.com/jhustata/intermediate/raw/main/donors.txt)
#    + [donors_recipients.dta](https://github.com/jhustata/intermediate/raw/main/donors_recipients.dta)
#    + [donors_recipients.txt](https://github.com/jhustata/intermediate/raw/main/donors_recipients.txt)
#    + [tx_yr.dta](https://github.com/jhustata/intermediate/raw/main/tx_yr.dta)
#    + [tx_yr.txt](https://github.com/jhustata/intermediate/raw/main/tx_yr.txt)
#
#
# ## Additional Resources and Evaluation
# - **Stata Version Note**: A specific note on Stata 13 usage and compatibility issues is available [here](pvalue.ipynb).
# - **Course Evaluation**: Your feedback is vital. Please participate in the course evaluation via [Course Evaluation System](https://courseevalsystem.publichealth.jhu.edu/User) in week 8.
# - **Stata-focused Discussion Community on GitHub**: An opportunity to engage with a [broader Hopkins community](https://github.com/jhufena/discussions/discussions) interested in Stata programming. Requires a GitHub account and a willingness to learn and share.
#
# ```{seealso}
# - Updated: 11:57AM, 04/23/2024
# ```
